# %%
import pandas as pd
import folium
from folium.plugins import HeatMap

# 1) Carregar dados
df = pd.read_csv("../data/locations.csv")

# 2) Criar mapa (centro provisório)
m = folium.Map(location=[38.72, -9.14], zoom_start=12)

# 3) Adicionar marcadores e coletar para heatmap
heat_data = []
for _, row in df.iterrows():
    lat, lon, val = row.latitude, row.longitude, row.valor_medio
    folium.CircleMarker(
        location=[lat, lon],
        radius=5,
        fill=True,
        fill_opacity=0.7,
        popup=f"{row.name}: €{val}"
    ).add_to(m)
    heat_data.append([lat, lon, val])

# 4) Adicionar HeatMap
HeatMap(heat_data, radius=25).add_to(m)

# 5) Ajustar bounds para todos os pontos
min_lat, max_lat = df.latitude.min(), df.latitude.max()
min_lon, max_lon = df.longitude.min(), df.longitude.max()
# fit_bounds espera [[south, west], [north, east]]
m.fit_bounds([[min_lat, min_lon], [max_lat, max_lon]])

# 6) Exibir
m
# 7) Salvar mapa
#m.save("../reports/lisbon_rent_map.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04fd2ba5e73d11b37610e8cc29ab849d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04fd2ba5e73d11b37610e8cc29ab849d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04fd2ba5e73d11b37610e8cc29ab849d = L.map(
#                 &quot;map_04fd2ba5e73d11b37610e8cc29ab849d&quot;,
#                 {
#                     center: [38.72, -9.14],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05873b17e8f58ff1c4c8924f14863e14 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05873b17e8f58ff1c4c8924f14863e14.addTo(map_04fd2ba5e73d11b37610e8cc29ab849d);
#
#
#             var circle_marker_6d17cdfc47ee10f8dc2406eab5f31699 = L.circleMarker(
#                 [38.752222, -9.224722],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_04fd2ba5e73d11b37610e8cc29ab849d);
#
#
#         var popup_24f2e21ce5654ced305786a2b7a349f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bf4e4c0107f6b56e95f242ac715cabc = $(`&lt;div id=&quot;html_4bf4e4c0107f6b56e95f242ac715cabc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0: €1350&lt;/div&gt;`)[0];
#                 popup_24f2e21ce5654ced305786a2b7a349f6.setContent(html_4bf4e4c0107f6b56e95f242ac715cabc);
#
#
#
#         circle_marker_6d17cdfc47ee10f8dc2406eab5f31699.bindPopup(popup_24f2e21ce5654ced305786a2b7a349f6)
#         ;
#
#
#
#
#             var circle_marker_2964dcf3df49a1600dea219800f99f0d = L.circleMarker(
#                 [38.757778, -9.218056],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_04fd2ba5e73d11b37610e8cc29ab849d);
#
#
#         var popup_00e1dc92c9f7394588db43ca1dd5f124 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_407eb4821d5a71a4cf8ac97282cb6044 = $(`&lt;div id=&quot;html_407eb4821d5a71a4cf8ac97282cb6044&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1: €1090&lt;/div&gt;`)[0];
#                 popup_00e1dc92c9f7394588db43ca1dd5f124.setContent(html_407eb4821d5a71a4cf8ac97282cb6044);
#
#
#
#         circle_marker_2964dcf3df49a1600dea219800f99f0d.bindPopup(popup_00e1dc92c9f7394588db43ca1dd5f124)
#         ;
#
#
#
#
#             var circle_marker_86fa6b2cf31ff0d695a40e22d9f1ed07 = L.circleMarker(
#                 [38.760278, -9.205],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_04fd2ba5e73d11b37610e8cc29ab849d);
#
#
#         var popup_80f08337ad747131b8fefe4718c44b76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca559419014dae601e6c7ad2050592c4 = $(`&lt;div id=&quot;html_ca559419014dae601e6c7ad2050592c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2: €1153&lt;/div&gt;`)[0];
#                 popup_80f08337ad747131b8fefe4718c44b76.setContent(html_ca559419014dae601e6c7ad2050592c4);
#
#
#
#         circle_marker_86fa6b2cf31ff0d695a40e22d9f1ed07.bindPopup(popup_80f08337ad747131b8fefe4718c44b76)
#         ;
#
#
#
#
#             var circle_marker_524d86bec0fc4e7ad78db71080f1c2d9 = L.circleMarker(
#                 [38.761389, -9.196667],
#                 {&quot;bubblingMouseEvents&quot;: t
