# %%
import pandas as pd
import folium
from folium.plugins import HeatMap

# 1) Carregar dados
df = pd.read_csv("../data/locations.csv")

# 2) Criar mapa (centro provisório)
m = folium.Map(location=[38.72, -9.14], zoom_start=12)

# 3) Adicionar marcadores e coletar para heatmap
heat_data = []
for _, row in df.iterrows():
    lat, lon, val = row.latitude, row.longitude, row.valor_medio
    folium.CircleMarker(
        location=[lat, lon],
        radius=5,
        fill=True,
        fill_opacity=0.7,
        popup=f"{row.name}: €{val}"
    ).add_to(m)
    heat_data.append([lat, lon, val])

# 4) Adicionar HeatMap
HeatMap(heat_data, radius=25).add_to(m)

# 5) Ajustar bounds para todos os pontos
min_lat, max_lat = df.latitude.min(), df.latitude.max()
min_lon, max_lon = df.longitude.min(), df.longitude.max()
# fit_bounds espera [[south, west], [north, east]]
m.fit_bounds([[min_lat, min_lon], [max_lat, max_lon]])

# 6) Exibir
m
# 7) Salvar mapa
m.save("../reports/lisbon_rent_map.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ec41ed4bb93664d22614ea907ddbc29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ec41ed4bb93664d22614ea907ddbc29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ec41ed4bb93664d22614ea907ddbc29 = L.map(
#                 &quot;map_8ec41ed4bb93664d22614ea907ddbc29&quot;,
#                 {
#                     center: [38.72, -9.14],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27cb37fa5737ece0a4393b09b3454704 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_27cb37fa5737ece0a4393b09b3454704.addTo(map_8ec41ed4bb93664d22614ea907ddbc29);
#
#
#             var circle_marker_e03a7449f8100bdb185a510c9a6458e4 = L.circleMarker(
#                 [38.752222, -9.224722],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8ec41ed4bb93664d22614ea907ddbc29);
#
#
#         var popup_d59f99d8358b9aee0be790bcef85eaa3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_860cf14871e415e46d1c1f8ee9706288 = $(`&lt;div id=&quot;html_860cf14871e415e46d1c1f8ee9706288&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0: €1350&lt;/div&gt;`)[0];
#                 popup_d59f99d8358b9aee0be790bcef85eaa3.setContent(html_860cf14871e415e46d1c1f8ee9706288);
#
#
#
#         circle_marker_e03a7449f8100bdb185a510c9a6458e4.bindPopup(popup_d59f99d8358b9aee0be790bcef85eaa3)
#         ;
#
#
#
#
#             var circle_marker_0dd1d02f9743d3767ae02588e7c5a023 = L.circleMarker(
#                 [38.757778, -9.218056],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8ec41ed4bb93664d22614ea907ddbc29);
#
#
#         var popup_83338ea14518dd61a81c1924584a7ad5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1166fd7eb38caece2859592cc373e7d8 = $(`&lt;div id=&quot;html_1166fd7eb38caece2859592cc373e7d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1: €1090&lt;/div&gt;`)[0];
#                 popup_83338ea14518dd61a81c1924584a7ad5.setContent(html_1166fd7eb38caece2859592cc373e7d8);
#
#
#
#         circle_marker_0dd1d02f9743d3767ae02588e7c5a023.bindPopup(popup_83338ea14518dd61a81c1924584a7ad5)
#         ;
#
#
#
#
#             var circle_marker_ebfc31c30d68da6fb4acf8c2582910fd = L.circleMarker(
#                 [38.760278, -9.205],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8ec41ed4bb93664d22614ea907ddbc29);
#
#
#         var popup_19eb4bb9749ae27363ceb9bd6004b59e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f958b21b2d806b7288b7093a84e6702 = $(`&lt;div id=&quot;html_7f958b21b2d806b7288b7093a84e6702&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2: €1153&lt;/div&gt;`)[0];
#                 popup_19eb4bb9749ae27363ceb9bd6004b59e.setContent(html_7f958b21b2d806b7288b7093a84e6702);
#
#
#
#         circle_marker_ebfc31c30d68da6fb4acf8c2582910fd.bindPopup(popup_19eb4bb9749ae27363ceb9bd6004b59e)
#         ;
#
#
#
#
#             var circle_marker_4defa63a8ddc68f700e28baa0c014449 = L.circleMarker(
#                 [38.761389, -9.196667],
#                 {&quot;bubblingMouseEvents&quot;: t
